# %%
df = pd.read_excel('Daily_Demand_Forecasting_Orders.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_excel('Daily_Demand_Forecasting_Orders.xlsx')
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
# 📦 Demand Forecasting using ARIMA
# Step 1: Load Libraries and Dataset

import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# Load the dataset
df = pd.read_excel('Daily_Demand_Forecasting_Orders.xlsx')

# Preview the dataset
df.head()
# Out:
#    Week of the month (first week, second, third, fourth or fifth week  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    Day of the week (Monday to Friday)  Non-urgent order  Urgent order  \
# 0                                   4           316.307       223.270
# 1                                   5           128.633        96.042
# 2                                   6            43.651        84.375
# 3                                   2           171.297       127.667
# 4                                   3            90.532       113.526
#
#    Order type A  Order type B  Order type C  Fiscal sector orders  \
# 0        61.543       175.586       302.448                 0.000
# 1        38.058        56.037       130.580                 0.000
# ...

# %%
# Step 2: Create a Time Index and Visualize Target Variable

# Add a simple time index (Day 1 to Day 60)
df['Time Index'] = range(1, len(df) + 1)

# Plot total orders over time
plt.figure(figsize=(12, 6))
plt.plot(df['Time Index'], df['Target (Total orders)'], marker='o')
plt.title('Total Orders Over Time')
plt.xlabel('Day (Index)')
plt.ylabel('Total Orders')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Step 3: Test for Stationarity using Augmented Dickey-Fuller Test

adf_result = adfuller(df['Target (Total orders)'])

print("ADF Statistic:", adf_result[0])
print("p-value:", adf_result[1])
print("Critical Values:")
for key, value in adf_result[4].items():
    print(f"   {key}: {value}")
# Out:
# ADF Statistic: -7.494948804576737
# p-value: 4.404699295229799e-11
# Critical Values:
#    1%: -3.5463945337644063
#    5%: -2.911939409384601
#    10%: -2.5936515282964665

# %%
# Step 4: Fit ARIMA Model and Forecast

# Fit ARIMA(1, 0, 1)
model = ARIMA(df['Target (Total orders)'], order=(1, 0, 1))
fitted_model = model.fit()

# Forecast the next 10 days
forecast_steps = 10
forecast = fitted_model.forecast(steps=forecast_steps)

# Plot actual and forecasted orders
plt.figure(figsize=(12, 6))
plt.plot(df['Time Index'], df['Target (Total orders)'], label='Historical Orders')
plt.plot(range(len(df)+1, len(df)+forecast_steps+1), forecast, label='Forecasted Orders', marker='o', color='orange')
plt.title('10-Day ARIMA Forecast for Total Orders')
plt.xlabel('Day (Index)')
plt.ylabel('Total Orders')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
## ✅ Conclusion

In this project, I used traditional ARIMA time series modeling to forecast daily order volume for a logistics company over a 10-day horizon. After verifying stationarity using the Augmented Dickey-Fuller test, I trained an ARIMA(1, 0, 1) model, which aligned well with historical trends and produced a reliable short-term forecast.

### Key Takeaways:
- ARIMA is effective for short-term logistics demand forecasting.
- Stationarity checks are essential for accurate forecasting.
- This model can be used by companies to optimize resources, inventory, and workforce.

---

## 🚀 Future Work
- Test additional models like ARIMA with auto-parameter tuning or SARIMA for seasonality.
- Compare with Prophet and machine learning models like Random Forest Regression or LSTM.
- Deploy as a Streamlit dashboard for real-time user interaction.
# Out:
#   Cell In[6], line 3
#     In this project, I used traditional ARIMA time series modeling to forecast daily order volume for a logistics company over a 10-day horizon. After verifying stationarity using the Augmented Dickey-Fuller test, I trained an ARIMA(1, 0, 1) model, which aligned well with historical trends and produced a reliable short-term forecast.
#        ^
# SyntaxError: invalid syntax

# %%
 Cell In[6], line 3
    In this project, I used traditional ARIMA time series modeling to forecast daily order volume for a logistics company over a 10-day horizon. After verifying stationarity using the Augmented Dickey-Fuller test, I trained an ARIMA(1, 0, 1) model, which aligned well with historical trends and produced a reliable short-term forecast.
       ^
SyntaxError: invalid syntax
# Out:
#   Cell In[7], line 1
#     Cell In[6], line 3
#          ^
# SyntaxError: invalid syntax
